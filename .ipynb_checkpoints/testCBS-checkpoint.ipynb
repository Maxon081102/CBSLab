# %%
from testsCBS import test_cbs_on_map
from time import time

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# test_cbs_on_map(0, 7, show_debug=False, show_all_solution=False)
def test_all(map_number, test_number):
    print("===============================")
    print("TEST on ", map_number, " test number ", test_number)
    t0 = time()
    # %time res = test_cbs_on_map(map_number, test_number, show_debug=False, show_all_solution=False, show_path=False)
    t1 = time()
    print("CBS: ", t1 - t0)
    t0 = time()
    # %time res = test_cbs_on_map(map_number, test_number, isCBS_CP=True, show_debug=False, show_all_solution=False, show_path=False)
    t1 = time()
    print("CBS_PC: ", t1 - t0)
    t0 = time()
    # %time res = test_cbs_on_map(map_number, test_number, isCBSH=True, show_debug=False, show_all_solution=False, show_path=False)
    t1 = time()
    print("CBSH: ", t1 - t0)
    print("===============================")

# %%
for i in range(9):
    test_all(0, i)
# Out:
# ...
# TEST on  0  test number  0
# CPU times: user 708 µs, sys: 29 µs, total: 737 µs
# Wall time: 739 µs
# CBS:  0.0012042522430419922
# CPU times: user 749 µs, sys: 1 µs, total: 750 µs
# Wall time: 752 µs
# CBS_PC:  0.0010528564453125
# CPU times: user 731 µs, sys: 0 ns, total: 731 µs
# Wall time: 734 µs
# CBSH:  0.0010950565338134766
# ...
# TEST on  0  test number  1
# CPU times: user 635 µs, sys: 104 µs, total: 739 µs
# Wall time: 635 µs
# CBS:  0.0009636878967285156
# CPU times: user 732 µs, sys: 1 µs, total: 733 µs
# Wall time: 738 µs
# CBS_PC:  0.001024007797241211
# CPU times: user 705 µs, sys: 1 µs, total: 706 µs
# Wall time: 707 µs
# CBSH:  0.001027822494506836
# ...
# TEST on  0  test number  2
# CPU times: user 12.6 ms, sys: 134 µs, total: 12.8 ms
# Wall time: 12.8 ms
# CBS:  0.013089179992675781
# CPU times: user 15.4 ms, sys: 174 µs, total: 15.6 ms
# Wall time: 15.6 ms
# CBS_PC:  0.015992164611816406
# CPU times: user 15 ms, sys: 127 µs, total: 15.1 ms
# Wall time: 15.1 ms
# ...
